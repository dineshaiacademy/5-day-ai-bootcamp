# %% [markdown]
# <a href="https://colab.research.google.com/github/dineshaiacademy/5-day-ai-bootcamp/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/dineshaiacademy/5-day-ai-bootcamp.git
# Out:
# Cloning into '5-day-ai-bootcamp'...
# remote: Enumerating objects: 62, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 62 (delta 15), reused 51 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (62/62), 12.78 KiB | 1.28 MiB/s, done.
# Resolving deltas: 100% (15/15), done.

# %%
import os
print(os.getcwd())
# Out:
# /content/5-day-ai-bootcamp

# %%
# %cd 5-day-ai-bootcamp
# Out:
# /content/5-day-ai-bootcamp/5-day-ai-bootcamp

# %%
import os
print(os.getcwd())
# Out:
# /content/5-day-ai-bootcamp/5-day-ai-bootcamp

# %%
from google.colab import userdata
token = userdata.get('OPENAI_API_KEY')
print(token)
# Out:
# Test Key

# %% [markdown]
# ## 🔐 Managing Secrets (VS Code + Colab)
#
# This cell loads API keys the same way whether the notebook runs locally in VS Code or in Google Colab.
#
# - **VS Code / local**: create a `.env` file (copy `.env.example`) with your keys. It is gitignored, so it never gets committed.
# - **Colab**: click the 🔑 key icon in the left sidebar, add your keys there, and enable notebook access.

# %%
# !pip install -q python-dotenv

# %%
import os

def get_secret(key_name):
    try:
        from google.colab import userdata
        return userdata.get(key_name)
    except ImportError:
        from dotenv import load_dotenv
        load_dotenv()
        return os.getenv(key_name)

OPENAI_API_KEY = get_secret("OPENAI_API_KEY")
GROQ_API_KEY = get_secret("GROQ_API_KEY")

# %%
OPENAI_API_KEY
# Out:
# 'Test Key'

# %%
# %cd Templates/streamlit-basic/
# Out:
# /content/5-day-ai-bootcamp/5-day-ai-bootcamp/Templates/streamlit-basic

# %%
# !pip install streamlit -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 77.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 72.4 MB/s eta 0:00:00

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏
# added 22 packages in 2s
# ⠏
# ⠏3 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏npm notice
# npm notice New major version of npm available! 10.8.2 -> 12.0.2
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v12.0.2
# npm notice To update run: npm install -g npm@12.0.2
# npm notice
# ⠏

# %%
# !streamlit run app.py &>/content/logs.txt &
# !npx localtunnel --port 8501
# Out:
# ⠙⠹⠸⠼⠴⠦^C

# %%
name = "Your Name"
print(name)
